# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import pygsheets
from sbn_yt_pu_crawler import Video, Channel, Search

# %%
# 티어링 시트 가져오기 : 시트ID로
gc = pygsheets.authorize(service_account_file='creds.json')
sheet_id = '14d-7E9FVLLp52-FtO674R4NG8moB_OeZt6gbvYNj_9w'
wks = gc.open_by_key(sheet_id)
sh = wks.worksheet_by_title('크롤링 필요') # 크롤링 필요한 시트
tiering = sh.get_as_df(has_header=True , index_column=None , start='A1', end='H100000' , numerize=True , empty_value=np.nan)
tiering
# Out:
#          통합 CRID            크리에이터명      소속     파트  담당자(정)  \
# 0    Creator1223             간송미술관     Ent  Ent 3     윤혜리
# 1    Creator0356               강과장     Ent    Biz     문준웅
# 2    Creator1063                강남     Ent  Ent 3    김민지C
# 3    Creator0356               강과장     Ent    Biz     문준웅
# 4    Creator0018               겜브링  Gaming   GP 2     유지웅
# ..           ...               ...     ...    ...     ...
# 401  Creator1074              HADA     Ent  Ent 4    김지혜C
# 402  Creator0710               M2U      기타     기타     NaN
# 403  Creator1134        syllyworld     Ent  Ent 4     윤소연
# 404      O&O0005  The Spawners_O&O     F&A  F&A.P     최은우
# 405      O&O0006       WHOOPEE_O&O     F&A  F&A.P     최은우
#
#                          채널ID                  채널명         채널 구분
# 0    UClafseA5goIBEpUlVR3bvmQ   미덕생활 Art Buff Life  크리에이터 (Main)
# 1    UC1EEpE0lA9BaArXhRTHIG6w                  강과장  크리에이터 (Main)
# 2    UCrAhzG4rf642oTUCpdyo5Vw  동네친구 강나미 [Kangnami]  크리에이터 (Main)
# 3    UCbln514BQwj3DHBOxdVlcyw                  상추씨   크리에이터 (Sub)
# 4    UCSOeJWyByeoBHpmrm0NnlLw       겜브링 GGAM BRING  크리에이터 (Main)
# ..                        ...                  ...           ...
# 401  UCYNio08m70spvq0ctpg-05A        하다필름 HADAFILM   크리에이터 (Sub)
# 402  UCfJsQeF3cJG1lZIhM5RfATQ                  M2U   크리에이터 (Sub)
# 403  UCyxws2tVARyRYgQ3AoM930g                  김장미  크리에이터 (Main)
# 404  UCmIq2waFVBotftEfK16f7lg              SPAWNER   크리에이터 (Sub)
# 405  UCnbYUGP5xtuc7-xfurDBLng             WHOOPEE!   크리에이터 (Sub)
#
# [406 rows x 8 columns]

# %%
data = Channel.Videos(channel_id='UC1-lwASmWqqU1V_WLNIRALw').extract()
df = pd.DataFrame(data)
df
# Out:
#        video_id                                  title published  length  \
# 0   i73pLRlAR3Q            땅 팠는데 억만장자 당첨?｜은밀한 도굴꾼들의 세계    20시간 전     473
# 1   z-IBFbMY_e8    조지 워싱턴의 틀니에 숨겨진 소름끼치는 비밀│몸으로 읽는 세계사      2일 전     455
# 2   nXEwSWhzbiE  제육볶음과 떡볶이가 소울푸드 된 이유는? ｜ 남녀 최애 음식의 역사      7일 전     445
# 3   OJNIvlgYk3A        ‘무차별 칼부림’ 대유행?!｜묻지마 범죄의 A부터 Z까지      2주 전     449
# 4   PenAZ18ZBt8            주식, 부동산 다 필요 없는 70년대 개이득 통장      2주 전     488
# ..          ...                                    ...       ...     ...
# 95  hpgLuRFjxME   춤신★춤왕 절대군주의 은밀한 취미 생활ㅣ코어 근육 랭킹 1위 운동      1년 전     398
# 96  sIQD1eOINQI                            한 주 쉬어가는 영상      1년 전      65
# 97  zC9MsBI2DX4   중세시대 마녀로 몰리면 벌어지는 일│인류 최악의 광기 '마녀사냥'      1년 전     450
# 98  uq7TPaPaLG8       취직했는데 상사가 아버지의 원수라면?ㅣ조선시대 원수 대처법      1년 전     378
# 99  BlvGp0n2pl0                      포브스 선정 화장실 필수품 1위      1년 전      81
#
#       views                                        description
# 0     57173  우리 어머님들이 그런 말 자주 하시잖아요.\n"땅을 파 봐라! 돈이 나오나?!"\n...
# 1     90262  📚『몸으로 읽는 세계사』정보📖\n교보문고: https://bit.ly/3ZQidn5...
# 2    418950  🥟교양만두 멤버십 가입하기 :https://www.youtube.com/channe...
# 3    194184  🥟교양만두 멤버십 가입하기 :https://www.youtube.com/channe...
# 4    107526  ※ 본 영상은 케이뱅크의 유료광고가 포함되어있습니다.\n\n👇생활비가 돌아오는 케이...
# ..      ...                                                ...
# 95   429892  진짜 1도 안어울리지만\n만두는 취미 운동으로 발레를 한다고 하는데요.\n보통 사람...
# 96   171282  오늘의 교양만두는 한 주 쉬어갑니다.\n기다려주신 여러분들께 정말 죄송합니다.\n다...
# 97   858228  영화나 동화 속 단골 빌런으로 등장하던 마녀.\n\n당연히 전설 속에서나 등장하는\...
# 98   725719  조선시대에도 로미오와 줄리엣 가문같이\n대대손손 내려오는 원수 집안이 존재했습니다....
# 99  1132219  전-하! 여러분 잘 지내셨나요?\n교양만두에서 책이 나왔습니다!\n제목은 [교양이 ...
#
# [100 rows x 6 columns]

# %%
channel_id_list = tiering[' 채널ID'].unique().tolist()
result_df = pd.DataFrame()

for i in tqdm(range(len(channel_id_list))):
    try:
        data = Channel.Videos(channel_id=channel_id_list[i]).extract() # limit=100, sort='newest' or 'oldest' or 'popular', target='3달 전' or ['3달 전', '4달 전']
        df = pd.DataFrame(data)
        df['channel_id'] = channel_id_list[i]
        result_df = pd.concat([result_df, df])
    except Exception as e:
        print("크롤링 오류:", e)

result_df
# Out:
#   5%|▍         | 19/406 [00:39<11:48,  1.83s/it]
# 크롤링 오류: expected string or bytes-like object, got 'NoneType'
#  78%|███████▊  | 315/406 [10:17<03:15,  2.14s/it]
# 크롤링 오류: 올바른 채널 ID를 입력해주세요.
#  87%|████████▋ | 352/406 [11:37<01:55,  2.15s/it]
# 크롤링 오류: 올바른 채널 ID를 입력해주세요.
#  94%|█████████▍| 382/406 [12:35<00:48,  2.04s/it]
# 크롤링 오류: 올바른 채널 ID를 입력해주세요.
# 100%|██████████| 406/406 [13:16<00:00,  1.96s/it]
#        video_id                                              title published  \
# 0   fPXVsHuvRi8  (EN) 한국인 최초로 칸 영화제에서 감독상 받은 그 영화 ※박찬욱 아님※/ 내레이...     8개월 전
# 1   IR6EUcCBBmA        (EN) 눈 오는 그림이 아니라고?❄🤷‍♀️ 미술품 복원 미스테리 [미덕생활]     9개월 전
# 2   -XIKYa26Z48     (EN) 불고기 논쟁도 한방에 해결한 한장의 그림 / 내레이션 #쓰복만 [미덕생활]    10개월 전
# 3   AdJaRH3BQ1g      (EN) 몇 백년 전 서울은 어떻게 생겼을까? / 내레이션 #주호민  [미덕생활]    10개월 전
# 4   bmjdQQ7EW5o  (EN) 복숭아가 논란의 중심이 된 이유, 복숭아가 귀신을 쫒는다고? / 내레이션 ...    11개월 전
# ..          ...                                                ...       ...
# 11  h16DovQQjhA                 ASMR👂I'm gonna melt down your ears      4년 전
# 12  XIgBkhHbdeg         I'm screwed after I ate something weird..🍄      4년 전
# 13  amw3DgRceVc                   WTH!! It's Terrible Nightmare!!😨      4년 전
# 14  cIVWzqoSxZI             Thank You for the YouTube Gold Button🥇      4년 전
# 15  4ZI7mKk0LjY                     Finally, I Have a New Camera!📹      4년 전
#
#     length     views                                        description  \
# 0    508.0    7282.0  #장승업 #취화선 #칸영화제 \n\n내레이션 : @G-movie \n\n📌Times...
# 1    676.0    2957.0  #삼일포 #심사정 #눈  \n\n여러분 삼일포 그림 속 비밀을 아시나요? \n눈 오...
# 2    442.0    3655.0  #주사거배 #풍속화 #선술집 #신윤복 #쓰복만\n\n📌Timestamp\n00:00...
# 3    450.0    7409.0  #압구정 #핫플 #정선 #주호민\n\n압구정, 도대체 언제부터 이렇게 핫했을까요?\...
# 4    458.0   52410.0  #복숭아 #귀신 #김홍도 #주호민\n\n딱복VS물복 여러분은 어떤 걸 더 선호하세요...
# ..     ...       ...                                                ...
# 11   547.0   13460.0  ASMR from Daily lives of Jackson and Charlotte...
# 12   394.0   23222.0  You guys shouldn't eat anything from the groun...
# 13   452.0    4629.0  This weekend.. I went hiking with Charlotte..\...
# 14   429.0  220664.0  It is hard to make a wish..😭\nI will upload va...
# 15   522.0   29372.0  It's my first video🎞\nI will upload various co...
#
#                   channel_id
# 0   UClafseA5goIBEpUlVR3bvmQ
# 1   UClafseA5goIBEpUlVR3bvmQ
# 2   UClafseA5goIBEpUlVR3bvmQ
# 3   UClafseA5goIBEpUlVR3bvmQ
# 4   UClafseA5goIBEpUlVR3bvmQ
# ..                       ...
# 11  UCnbYUGP5xtuc7-xfurDBLng
# 12  UCnbYUGP5xtuc7-xfurDBLng
# 13  UCnbYUGP5xtuc7-xfurDBLng
# 14  UCnbYUGP5xtuc7-xfurDBLng
# 15  UCnbYUGP5xtuc7-xfurDBLng
#
# [32476 rows x 7 columns]

# %%
result_df['published'].unique()
# Out:
# array(['8개월 전', '9개월 전', '10개월 전', '11개월 전', '1년 전', '4일 전', '7일 전',
#        '11일 전', '2주 전', '3주 전', '1개월 전', '2개월 전', '3개월 전', '4개월 전',
#        '5개월 전', '6개월 전', '7개월 전', '3일 전', '10일 전', '8일 전', '2년 전',
#        '44분 전', '2일 전', '5일 전', '6일 전', '9일 전', '12일 전', '13일 전', '4주 전',
#        '3년 전', '23시간 전', '21시간 전', '1일 전', '6년 전', '1시간 전', '4시간 전',
#        '5시간 전', '6시간 전', '7시간 전', '22시간 전', '45분 전', '16시간 전', '4년 전',
#        '18시간 전', '7년 전', '8년 전', '19시간 전', '9시간 전', '3시간 전', '5년 전',
#        '2시간 전', '50분 전', '51분 전', '36분 전', '20시간 전', '17시간 전', '8시간 전',
#        '55분 전', '9년 전'], dtype=object)

# %%
# 2023.01.01 ~ 2023.08.31 사이 영상만 추출
filtered_df = result_df[~result_df['published'].str.contains('년 전')]
filtered_df = filtered_df[~filtered_df['published'].str.contains('시간 전')]
filtered_df = filtered_df[~filtered_df['published'].str.contains('분 전')]
filtered_df = filtered_df[~filtered_df['published'].str.contains('일 전')]
filtered_df = filtered_df[~filtered_df['published'].str.contains('1개월 전')] # 9월 제외
filtered_df
# Out:
#        video_id                                              title published  \
# 0   fPXVsHuvRi8  (EN) 한국인 최초로 칸 영화제에서 감독상 받은 그 영화 ※박찬욱 아님※/ 내레이...     8개월 전
# 1   IR6EUcCBBmA        (EN) 눈 오는 그림이 아니라고?❄🤷‍♀️ 미술품 복원 미스테리 [미덕생활]     9개월 전
# 2   -XIKYa26Z48     (EN) 불고기 논쟁도 한방에 해결한 한장의 그림 / 내레이션 #쓰복만 [미덕생활]    10개월 전
# 3   AdJaRH3BQ1g      (EN) 몇 백년 전 서울은 어떻게 생겼을까? / 내레이션 #주호민  [미덕생활]    10개월 전
# 3   U3qiay9zaX0  30대 부부 일상 브이로그 / 처음으로 어린이집 보내고 데이트하기 /  9개월 아기...      2주 전
# ..          ...                                                ...       ...
# 32  zYIBaftammI           LCK선수의 치솟는 연봉, 연봉 상한선은 필요한가? [ 출입금G #6 ]    10개월 전
# 1   WjZlBZk1Gko  현실적인 T와 F의 이상형 토크❤ 30대인 우리가 돌싱글즈에 몰입할 수 밖에 없는 ...      2주 전
# 2   7Z393Nz8G9o  '악마는 프라다를 입는다' 현실판😈 청담샵 이사님과의 진솔한 알콜 데이트 | 에이바...      3주 전
# 3   YaTUnKalAy8  𝐕𝐋𝐎𝐆 : 데이트 가는 날💕 찐친들과 함께하는 사랑스러운 일상 기록│ OOTD, ...      3주 전
# 8   Jz4AIsI5jxE  오랜만이에요! 요즘 제 근황은...🥰 옷 잘 입는 패션 업계 친구들과 함께 한 걸스...     2개월 전
#
#     length     views                                        description  \
# 0    508.0    7282.0  #장승업 #취화선 #칸영화제 \n\n내레이션 : @G-movie \n\n📌Times...
# 1    676.0    2957.0  #삼일포 #심사정 #눈  \n\n여러분 삼일포 그림 속 비밀을 아시나요? \n눈 오...
# 2    442.0    3655.0  #주사거배 #풍속화 #선술집 #신윤복 #쓰복만\n\n📌Timestamp\n00:00...
# 3    450.0    7409.0  #압구정 #핫플 #정선 #주호민\n\n압구정, 도대체 언제부터 이렇게 핫했을까요?\...
# 3   1075.0  110169.0  이번 영상에서는 미래에셋증권 앱에서 하윤이 주식계좌를 만들어줬어요. 앞으로 잘 투자...
# ..     ...       ...                                                ...
# 32  1125.0   87517.0  #G식의밤  #허튜브 #조학동 #메탈킴 #리라\n\n⚠️본 영상은 주제에 관한 신랄...
# 1    656.0   69505.0  안녕하세요 여러분~ 오늘은 햇살이 좋은 어느 날 🌞 \n돌싱글즈4 에 출연 중인 제...
# 2    753.0    6005.0  안녕하세요 여러분~~\n오늘은 무려 5년 동안이나 제 헤어를 담당해 주신 에이바이봄...
# 3    349.0    4080.0  오늘은 짧지만 행복했던 찐친들과의 데이트 브이로그 입니다! \n\n평소 너무너무 좋...
# 8    580.0    6124.0  안녕하세요, 여러분\n오랜만에 돌아온 syllyworld 브이로그 입니다 :)\n\...
#
#                   channel_id
# 0   UClafseA5goIBEpUlVR3bvmQ
# 1   UClafseA5goIBEpUlVR3bvmQ
# 2   UClafseA5goIBEpUlVR3bvmQ
# 3   UClafseA5goIBEpUlVR3bvmQ
# 3   UC1EEpE0lA9BaArXhRTHIG6w
# ..                       ...
# 32  UCjSCrz_zsSCEKbbnHQiqjmA
# 1   UCyxws2tVARyRYgQ3AoM930g
# 2   UCyxws2tVARyRYgQ3AoM930g
# 3   UCyxws2tVARyRYgQ3AoM930g
# 8   UCyxws2tVARyRYgQ3AoM930g
#
# [15701 rows x 7 columns]

# %%
filtered_df = filtered_df[['channel_id','video_id','title','published','views']]
filtered_df = filtered_df.reset_index(drop=True)
filtered_df
# Out:
#                      channel_id     video_id  \
# 0      UClafseA5goIBEpUlVR3bvmQ  fPXVsHuvRi8
# 1      UClafseA5goIBEpUlVR3bvmQ  IR6EUcCBBmA
# 2      UClafseA5goIBEpUlVR3bvmQ  -XIKYa26Z48
# 3      UClafseA5goIBEpUlVR3bvmQ  AdJaRH3BQ1g
# 4      UC1EEpE0lA9BaArXhRTHIG6w  U3qiay9zaX0
# ...                         ...          ...
# 15696  UCjSCrz_zsSCEKbbnHQiqjmA  zYIBaftammI
# 15697  UCyxws2tVARyRYgQ3AoM930g  WjZlBZk1Gko
# 15698  UCyxws2tVARyRYgQ3AoM930g  7Z393Nz8G9o
# 15699  UCyxws2tVARyRYgQ3AoM930g  YaTUnKalAy8
# 15700  UCyxws2tVARyRYgQ3AoM930g  Jz4AIsI5jxE
#
#                                                    title published     views
# 0      (EN) 한국인 최초로 칸 영화제에서 감독상 받은 그 영화 ※박찬욱 아님※/ 내레이...     8개월 전    7282.0
# 1            (EN) 눈 오는 그림이 아니라고?❄🤷‍♀️ 미술품 복원 미스테리 [미덕생활]     9개월 전    2957.0
# 2         (EN) 불고기 논쟁도 한방에 해결한 한장의 그림 / 내레이션 #쓰복만 [미덕생활]    10개월 전    3655.0
# 3          (EN) 몇 백년 전 서울은 어떻게 생겼을까? / 내레이션 #주호민  [미덕생활]    10개월 전    7409.0
# 4      30대 부부 일상 브이로그 / 처음으로 어린이집 보내고 데이트하기 /  9개월 아기...      2주 전  110169.0
# ...                                                  ...       ...       ...
# 15696           LCK선수의 치솟는 연봉, 연봉 상한선은 필요한가? [ 출입금G #6 ]    10개월 전   87517.0
# 15697  현실적인 T와 F의 이상형 토크❤ 30대인 우리가 돌싱글즈에 몰입할 수 밖에 없는 ...      2주 전   69505.0
# 15698  '악마는 프라다를 입는다' 현실판😈 청담샵 이사님과의 진솔한 알콜 데이트 | 에이바...      3주 전    6005.0
# 15699  𝐕𝐋𝐎𝐆 : 데이트 가는 날💕 찐친들과 함께하는 사랑스러운 일상 기록│ OOTD, ...      3주 전    4080.0
# 15700  오랜만이에요! 요즘 제 근황은...🥰 옷 잘 입는 패션 업계 친구들과 함께 한 걸스...     2개월 전    6124.0
#
# [15701 rows x 5 columns]

# %%
# 결과 구글 시트에 저장
gc = pygsheets.authorize(service_account_file='creds.json')
sheet_id = '14d-7E9FVLLp52-FtO674R4NG8moB_OeZt6gbvYNj_9w'
sh = gc.open_by_key(sheet_id)

# 오류 발생 시, worksheet의 행 수 늘려서 재실행
wks = sh.worksheet_by_title('크롤링 완료') # wks = sh.add_worksheet()
wks.set_dataframe(filtered_df, 'A1', index=False)

# # 결과 구글 시트에 저장
# gc = pygsheets.authorize(service_account_file='creds.json')
# sheetname= '크롤링 시도'
# sh = gc.open(sheetname)

# # 오류 발생 시, worksheet의 행 수 늘려서 재실행
# wks = sh.worksheet_by_title('Gaming 0/1')
# wks.set_dataframe(filtered_df, 'A1', index=False)
