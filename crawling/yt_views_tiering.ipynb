# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import pygsheets
from sbn_yt_pu_crawler import Video, Channel, Search
# 성현님 패키지

# %%
# 티어링 시트 가져오기 : 시트ID로
gc = pygsheets.authorize(service_account_file='creds.json')
sheet_id = '14d-7E9FVLLp52-FtO674R4NG8moB_OeZt6gbvYNj_9w'
wks = gc.open_by_key(sheet_id)
sh = wks.worksheet_by_title('크롤링 필요 (2)') # 크롤링 필요한 시트
tiering = sh.get_as_df(has_header=True , index_column=None , start='A1', end='H100000' , numerize=True , empty_value=np.nan)
tiering
# Out:
#            통합 CRID       크리에이터명          소속          파트  담당자(정)  \
# 0      Creator0751          군림보      Gaming        GP 1     한규열
# 1    Creator0220-1        급식게임즈         F&A       F&A 1     김세민
# 2      Creator0023          김블루      Gaming          공통     하헌재
# 3      Creator0023          김블루      Gaming          공통     하헌재
# 4      Creator0520          도진이         Ent       Ent 4     조윤영
# ..             ...          ...         ...         ...     ...
# 570    Creator0432  유창현_esports          외부          외부     NaN
# 571    Creator0715          한은경          외부          외부     NaN
# 572    Creator0708        DDUNG          외부          외부     NaN
# 573    Creator1184        bebop      Global      Global     안기표
# 574    Creator0517          양노을  COO office  COO office     오세혁
#
#                          채널ID                   채널명         채널 구분
# 0    UC9u6kHr_o_xB0i41P9eM-Tg               군림보 풀영상   크리에이터 (Sub)
# ...

# %%
# data = Channel.Videos(channel_id='UC1-lwASmWqqU1V_WLNIRALw').extract()
# df = pd.DataFrame(data)
# df

# %%
channel_id_list = tiering[' 채널ID'].unique().tolist()
result_df = pd.DataFrame()

for i in tqdm(range(len(channel_id_list))):
    try:
        data = Channel.Videos(channel_id=channel_id_list[i]).extract() # limit=100, sort='newest' or 'oldest' or 'popular', target='3달 전' or ['3달 전', '4달 전']
        df = pd.DataFrame(data)
        df['channel_id'] = channel_id_list[i]
        result_df = pd.concat([result_df, df])
    except Exception as e:
        print("크롤링 오류:", e)

result_df
# Out:
#   8%|▊         | 44/575 [01:10<22:52,  2.58s/it]
# 크롤링 오류: 올바른 채널 ID를 입력해주세요.
#   8%|▊         | 48/575 [01:19<23:24,  2.67s/it]
# 크롤링 오류: 올바른 채널 ID를 입력해주세요.
# 크롤링 오류: 올바른 채널 ID를 입력해주세요.
#  65%|██████▌   | 374/575 [25:24<08:19,  2.49s/it]
# 크롤링 오류: 올바른 채널 ID를 입력해주세요.
# 100%|██████████| 575/575 [39:00<00:00,  4.07s/it]
#        video_id                                              title published  \
# 0   2kaUCyX_Er4    AKM 기록 보유자가 한국맵 태이고에서 AKM를 써본 다면? 【배틀그라운드】【풀영상】      2년 전
# 1   5z9v0JU3Sek   대상의 정체를 몰래 알아 낼수 있는 새로운 직업! 파파라치 모드 【어몽어스】 【풀영상】      2년 전
# 2   ExCa0sA2UUE  한방에 날려버린다!! 무엇이든 튕겨낼수 있는 새로운 직업! 쿠마 모드 【어몽어스】 ...      2년 전
# 3   -tLjYJL0ys8       전부 똑같은 색으로 어몽어스를 하면 일어나는 일ㅋㅋㅋ 미치겠다ㅋㅋㅋㅋ 【풀영상】      2년 전
# 4   aNbzltFa7g8               【풀영상】어몽어스를 15명이서 하면 일어나는 일ㅋㅋㅋㅋ 대박ㅋㅋㅋ      2년 전
# ..          ...                                                ...       ...
# 69  JeMGlmOYPCQ                                              가족오락관      4년 전
# ...

# %%
result_df['published'].unique()
# Out:
# array(['2년 전', '6년 전', '1년 전', '3년 전', '4년 전', '5년 전', '11개월 전', '7년 전',
#        '8년 전', '9년 전', '5개월 전', '7개월 전', '6개월 전', '8개월 전', '9개월 전',
#        '10개월 전', '3일 전', '2주 전', '3주 전', '1개월 전', '2개월 전', '3개월 전',
#        '4개월 전', '1일 전', '2일 전', '4일 전', '9일 전', '13일 전', '4주 전', '5일 전',
#        '7일 전', '10일 전', '12일 전', '8일 전', '21시간 전', '6일 전', '11일 전',
#        '19시간 전', '10시간 전', '13시간 전', '14시간 전', '20시간 전', '17시간 전',
#        '15시간 전', '1시간 전', '18시간 전', '22시간 전', '2시간 전', '23시간 전', '12시간 전',
#        '3시간 전', '12분 전'], dtype=object)

# %%
# 2023.01.01 ~ 2023.08.31 사이 영상만 추출
filtered_df = result_df[~result_df['published'].str.contains('년 전')]
filtered_df = filtered_df[~filtered_df['published'].str.contains('시간 전')]
filtered_df = filtered_df[~filtered_df['published'].str.contains('분 전')]
filtered_df = filtered_df[~filtered_df['published'].str.contains('일 전')]
filtered_df = filtered_df[~filtered_df['published'].str.contains('1개월 전')] # 9월 제외
filtered_df
# Out:
#        video_id                                              title published  \
# 0   X0wn8IV6BkE               세상살이 걱정많던 여자가 이걸 하고 세상을 열심히 살고싶어졌습니다     5개월 전
# 1   HYoKrUtBilk                      광우상사가서 단독콘서트 하고 왔습니다-체력이슈 !!!     7개월 전
# 2   rjgI_jFrAxI  vlog | 고소한 겉바속촉 스콘과 겨울에먹는얼큰한 꽃게탕, 김치에 라면 조합으로 ...     7개월 전
# 0   DsSHmzQOhWQ             레이저제모 10회 채워야한다? 중간에 멈추면 안되는 이유 [강남언니]     6개월 전
# 1   wnNby9gM7m4        리프팅 만족도 최상! 강력한 신상 리프팅레이저 리니어지의 모든 것 [강남언니]     7개월 전
# ..          ...                                                ...       ...
# 4   u5LJ6nEzeK4                  광산 꼬불꼬불 다운힐 천상계 주행 " 카트라이더 드리프트 "     6개월 전
# 5   pv84WK4LrKs                 신 맵 + 신 차 + 유창현   “ 카트라이더 : 드리프트 “     7개월 전
# 6   CjcoDvNL1XU                              아슬아슬 다리 난간 타는 붐힐 드라이브     7개월 전
# 7   iWK5N5mC1Rs                              카트라이더 : 드리프트 극한으로 달리기     8개월 전
# 8   e0LW2MqLuNE                 유창현 카트라이더 드리프트 빌리지 고가의 질주 2.01.864     8개월 전
#
# ...

# %%
filtered_df = filtered_df[['channel_id','video_id','title','published','views']]
filtered_df = filtered_df.reset_index(drop=True)
filtered_df
# Out:
#                      channel_id     video_id  \
# 0      UCLpcnwUDpUlzh9XsutB1q5g  X0wn8IV6BkE
# 1      UCLpcnwUDpUlzh9XsutB1q5g  HYoKrUtBilk
# 2      UCLpcnwUDpUlzh9XsutB1q5g  rjgI_jFrAxI
# 3      UCSD5QgeqDVysv_1gBiPKN6Q  DsSHmzQOhWQ
# 4      UCSD5QgeqDVysv_1gBiPKN6Q  wnNby9gM7m4
# ...                         ...          ...
# 12289  UCQCqzTme_YDBe93rQpWgEeg  u5LJ6nEzeK4
# 12290  UCQCqzTme_YDBe93rQpWgEeg  pv84WK4LrKs
# 12291  UCQCqzTme_YDBe93rQpWgEeg  CjcoDvNL1XU
# 12292  UCQCqzTme_YDBe93rQpWgEeg  iWK5N5mC1Rs
# 12293  UCQCqzTme_YDBe93rQpWgEeg  e0LW2MqLuNE
#
#                                                    title published    views
# 0                   세상살이 걱정많던 여자가 이걸 하고 세상을 열심히 살고싶어졌습니다     5개월 전    741.0
# 1                          광우상사가서 단독콘서트 하고 왔습니다-체력이슈 !!!     7개월 전   4293.0
# 2      vlog | 고소한 겉바속촉 스콘과 겨울에먹는얼큰한 꽃게탕, 김치에 라면 조합으로 ...     7개월 전    411.0
# 3                 레이저제모 10회 채워야한다? 중간에 멈추면 안되는 이유 [강남언니]     6개월 전   3975.0
# ...

# %%
# 채널ID 구독자 크롤링
channel_id_list_2 = ['UCaD7orYFMyjLgtI8IkZccnQ','UCx8IhwapX8E7uooFYJIeVZw','UC2VkRjliM6uX5taeDO1IzEA','UCzgst-b7bbFuBpGhyB8qQHw','UCJ4ETdbjB1MDhjwEZDtUlBQ','Cl-91gEJmqkQIrIF80-1m2w',
                     'UC0Fh8z-dTpIbtIWWm68ZTwQ','UCBZb4Efl7nTfoOGVp8quqlg','UCv_vC5hIFslRAR3i8tkD3EA','UCk9ARWxsAze5NHl7XCa5_WA','UCI_WD1FUnkhMAnR-ntqW5rA','UCV9mpAmNifUREiGhI0PokZQ',
                     'UCW99_pwOr9JvzjZ81bMMjSg','UCj7mdvAJCRKvGBmcusOr9Ag','UCbFDSHnru84Z0bEIVM8Oesw','UCFPR5ecrgGzlPhjdXUzd6qA','UCXVOyRDpaAVTtUILUMtIT6g','UCwEsEn83TIqwb7wbkLEOMRw',
                     'UCqbpna45EO7qaARGv2vgjkg','UCiUbJuYVtmxAVDbXuoeZDlw']
result_df_2 = pd.DataFrame()

for i in tqdm(range(len(channel_id_list_2))):
    try:
        data_2 = Channel.About(channel_id=channel_id_list_2[i]).extract() # limit=100, sort='newest' or 'oldest' or 'popular', target='3달 전' or ['3달 전', '4달 전']
        df_2 = pd.DataFrame(data_2)
        df_2['channel_id'] = channel_id_list_2[i]
        result_df_2 = pd.concat([result_df_2, df_2])
    except Exception as e:
        print("크롤링 오류:", e)

result_df_2
# Out:
#   5%|▌         | 1/20 [00:00<00:10,  1.73it/s]
# 크롤링 오류: list index out of range
#  25%|██▌       | 5/20 [00:02<00:08,  1.72it/s]
# 크롤링 오류: 올바른 채널 ID를 입력해주세요.
#  35%|███▌      | 7/20 [00:03<00:05,  2.31it/s]
# 크롤링 오류: list index out of range
#  40%|████      | 8/20 [00:04<00:05,  2.16it/s]
# 크롤링 오류: list index out of range
#  45%|████▌     | 9/20 [00:04<00:05,  2.03it/s]
# 크롤링 오류: list index out of range
#  50%|█████     | 10/20 [00:05<00:05,  1.86it/s]
# 크롤링 오류: list index out of range
#  55%|█████▌    | 11/20 [00:05<00:04,  1.83it/s]
# 크롤링 오류: list index out of range
#  60%|██████    | 12/20 [00:06<00:04,  1.82it/s]
# 크롤링 오류: list index out of range
#  65%|██████▌   | 13/20 [00:06<00:03,  1.81it/s]
# 크롤링 오류: list index out of range
#  70%|███████   | 14/20 [00:07<00:03,  1.77it/s]
# 크롤링 오류: list index out of range
#  75%|███████▌  | 15/20 [00:08<00:02,  1.79it/s]
# 크롤링 오류: list index out of range
#  80%|████████  | 16/20 [00:08<00:02,  1.78it/s]
# 크롤링 오류: list index out of range
# ...

# %%
# data_3 = Channel.About(channel_id='UCiUbJuYVtmxAVDbXuoeZDlw').extract()
# df_3 = pd.DataFrame(data_3)
# df_3

# %%
data = Channel.Videos(channel_id='UCwl9OALh8IMwSv_kFdHlMDA').extract()
df = pd.DataFrame(data)
df
# Out:
#        video_id                                              title published  \
# 0   wFDNaMOfLfo                             말이됩니까??? 타조는 대체 얼마일까??      1일 전
# 1   1h_TGh6aaVo        역대급 벌레지옥 죽음의도로!! 수억마리는 터져죽었을텐데 그래도 계속 나옵니다.      1일 전
# 2   VKpMFWIG1Bc        두꺼비 50마리를 약으로 절였더니 나오는것들입니다!! 올해는 특히나 풍년이네요      4일 전
# 3   LOeVb6Wi-g4                      씨몽키가 몰살했습니다... 특단의 조치를 내렸습니다.      5일 전
# 4   C02k8-jEx50        너무 역겹고 충격적이라 고민했습니다. 심각성이 보이나요?? 정말 조심해야합니다      8일 전
# ..          ...                                                ...       ...
# 95  S-80p7wKEeM      어쩌죠ㅋㅋ 아기 카멜레온이 한박스 왔습니다. 심장아프게 귀여운 생명체를 소개합니다     5개월 전
# 96  DoIJcwTR6MA  국가생물이 밀수되었습니다 ㄷㄷ.... 60만원에 팔리고있는 전세계적인 희귀종을 찾아...     5개월 전
# 97  dH-0z63t_q4     여기서 아기"콜덕" 두마리가 태어났습니다ㅋㅋㅋ어미가 포기했는데 오히려 럭키네요...     5개월 전
# 98  bVFCy45QW1c                     이빨을뽑아서 수출된다는 슬로우로리스는 대체 얼마일까??     5개월 전
# 99  6fJHhWhK_1o                          충격...시장 슈가글라이더는 대체 얼마일까??     5개월 전
#
# ...

# %%
# 2023.01.01 ~ 2023.08.31 사이 영상만 추출
filtered_df = df[~df['published'].str.contains('년 전')]
filtered_df = filtered_df[~filtered_df['published'].str.contains('시간 전')]
filtered_df = filtered_df[~filtered_df['published'].str.contains('분 전')]
filtered_df = filtered_df[~filtered_df['published'].str.contains('일 전')]
filtered_df = filtered_df[~filtered_df['published'].str.contains('1개월 전')] # 9월 제외
filtered_df
# Out:
#        video_id                                              title published  \
# 6   ZRpgqhuQyvg          맛있다던 사람 나와보세요.. 사상 최악의 음식 개미볶음밥을 만들어봤습니다.      2주 전
# 7   7jcFi5jKFC8                 발견 자체가 기적입니다!! 하늘이 내려준 작은선물 꿀떡이 1화      2주 전
# 8   vWShBBNozhM  이빨때문에 살떨리네요...!! 5년만에 도착했는데 CG보다 더 살벌합니다. 아마존에...      2주 전
# 9   wiE5rfGG0TY         씨몽키 이번엔 100만마리입니다!! 결국 저질렀는데 감당이 될지 모르겠습니다      2주 전
# 10  hr5lchjTu14  싱싱한 장수말벌 둥지를 개미수조에 부었습니다. 거의 유일한 천적이죠? 간만에 개미먹...      2주 전
# ..          ...                                                ...       ...
# 95  S-80p7wKEeM      어쩌죠ㅋㅋ 아기 카멜레온이 한박스 왔습니다. 심장아프게 귀여운 생명체를 소개합니다     5개월 전
# 96  DoIJcwTR6MA  국가생물이 밀수되었습니다 ㄷㄷ.... 60만원에 팔리고있는 전세계적인 희귀종을 찾아...     5개월 전
# 97  dH-0z63t_q4     여기서 아기"콜덕" 두마리가 태어났습니다ㅋㅋㅋ어미가 포기했는데 오히려 럭키네요...     5개월 전
# 98  bVFCy45QW1c                     이빨을뽑아서 수출된다는 슬로우로리스는 대체 얼마일까??     5개월 전
# 99  6fJHhWhK_1o                          충격...시장 슈가글라이더는 대체 얼마일까??     5개월 전
#
# ...

# %%
filtered_df = filtered_df[['video_id','title','published','views']]
filtered_df = filtered_df.reset_index(drop=True)
filtered_df
# Out:
#        video_id                                              title published  \
# 0   ZRpgqhuQyvg          맛있다던 사람 나와보세요.. 사상 최악의 음식 개미볶음밥을 만들어봤습니다.      2주 전
# 1   7jcFi5jKFC8                 발견 자체가 기적입니다!! 하늘이 내려준 작은선물 꿀떡이 1화      2주 전
# 2   vWShBBNozhM  이빨때문에 살떨리네요...!! 5년만에 도착했는데 CG보다 더 살벌합니다. 아마존에...      2주 전
# 3   wiE5rfGG0TY         씨몽키 이번엔 100만마리입니다!! 결국 저질렀는데 감당이 될지 모르겠습니다      2주 전
# 4   hr5lchjTu14  싱싱한 장수말벌 둥지를 개미수조에 부었습니다. 거의 유일한 천적이죠? 간만에 개미먹...      2주 전
# ..          ...                                                ...       ...
# 72  S-80p7wKEeM      어쩌죠ㅋㅋ 아기 카멜레온이 한박스 왔습니다. 심장아프게 귀여운 생명체를 소개합니다     5개월 전
# 73  DoIJcwTR6MA  국가생물이 밀수되었습니다 ㄷㄷ.... 60만원에 팔리고있는 전세계적인 희귀종을 찾아...     5개월 전
# 74  dH-0z63t_q4     여기서 아기"콜덕" 두마리가 태어났습니다ㅋㅋㅋ어미가 포기했는데 오히려 럭키네요...     5개월 전
# 75  bVFCy45QW1c                     이빨을뽑아서 수출된다는 슬로우로리스는 대체 얼마일까??     5개월 전
# 76  6fJHhWhK_1o                          충격...시장 슈가글라이더는 대체 얼마일까??     5개월 전
#
#      views
# 0    42123
# 1    43086
# ...

# %%
# 결과 구글 시트에 저장
gc = pygsheets.authorize(service_account_file='creds.json')
sheet_id = '14d-7E9FVLLp52-FtO674R4NG8moB_OeZt6gbvYNj_9w'
sh = gc.open_by_key(sheet_id)

# 오류 발생 시, worksheet의 행 수 늘려서 재실행
wks = sh.worksheet_by_title('크롤링 완료') # wks = sh.add_worksheet()
wks.set_dataframe(filtered_df, 'B27997', index=False)

# # 결과 구글 시트에 저장
# gc = pygsheets.authorize(service_account_file='creds.json')
# sheetname= '크롤링 시도'
# sh = gc.open(sheetname)

# # 오류 발생 시, worksheet의 행 수 늘려서 재실행
# wks = sh.worksheet_by_title('Gaming 0/1')
# wks.set_dataframe(filtered_df, 'A1', index=False)
